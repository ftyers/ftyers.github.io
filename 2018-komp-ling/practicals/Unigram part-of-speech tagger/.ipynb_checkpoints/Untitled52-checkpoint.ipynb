# %%
import re

# %%
s = 'Привет мир!'
re.search(r'м[а-я]+', s).group()
# Out:
# 'мир'

# %%
re.search(r'м[а-я]+', s).span()
# Out:
# (7, 10)

# %%
re.sub('[а-я]', 'x', s)
# Out:
# 'Пxxxxx xxx!'

# %%
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# # ElementTree

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('C:\\input\\isl-ex.xml')

# %%
root = tree.getroot()

print(root.tag)
# Out:
# xigt-corpus

# %%
for tier in root.findall('.//tier'):
        if tier.attrib['id'] == 'n':
                for item in tier.findall('.//item'):
                        print(item.text)
# Out:
# (Þau) Jón og María eru vinir.
# they.NEUT Jón og María are friends
# Jón and María are friends.

# %%
How would you get just the Icelandic line and the gloss line ?

# %% [markdown]
# # scikit learn

# %%
from sklearn.linear_model import perceptron

# %%
words = []    # The word, correct label and pronunciation
data = []     # Training examples, e.g. feature vectors
labels = []   # Correct labels

# %%
file = 'C:\\input\\pronunciation_data.tsv'
for line in open(file, encoding = "utf-8").readlines():
    row = line.strip().split('\t')
    vec = []
    for i in row[3].split(','):
            vec.append(int(i))
    data.append(vec)
    labels.append(int(row[0]))
    words.append((row[1], row[2], int(row[0])))

# %%
net = perceptron.Perceptron(n_iter=100, verbose=0, random_state=None, fit_intercept=True, eta0=0.002)
net.fit(data,labels)
# Out:
# C:\Users\Admin\Anaconda2\envs\py36\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Perceptron(alpha=0.0001, class_weight=None, eta0=0.002, fit_intercept=True,
#       max_iter=None, n_iter=100, n_jobs=1, penalty=None, random_state=None,
#       shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
result = net.predict(data)
total = 0
correct = 0
for i in range(0, len(words)):
    if result[i] == words[i][2]:
        print('+', result[i], words[i]);
        correct = correct + 1
    else:
        print('-', result[i], words[i]);
    total = total + 1
print(correct/total)
# Out:
# + 0 ('#аббатство#', '[ɐˈb(ː)at͡stvə]', 0)
# + 0 ('#аббревиатура#', '[ɐbrʲɪvʲɪɐˈturə]', 0)
# + 0 ('#авангард#', '[ɐvɐnˈɡart]', 0)
# + 0 ('#аванс#', '[ɐˈvans]', 0)
# + 0 ('#авансцена#', '[ɐvɐnˈst͡sɛnə]', 0)
# + 0 ('#авантюра#', '[ɐvɐnʲˈtʲurə]', 0)
# + 0 ('#авантюрист#', '[ɐvənʲtʲʉˈrʲist]', 0)
# + 0 ('#аварец#', '[ɐˈvarʲɪt͡s]', 0)
# + 0 ('#авария#', '[ɐˈvarʲɪjə]', 0)
# + 0 ('#август#', '[ˈavɡʊst]', 0)
# + 0 ('#авиабаза#', '[ˌavʲɪɐˈbazə]', 0)
# + 0 ('#авиакомпания#', '[ˌavʲɪəkɐmˈpanʲɪjə]', 0)
# + 0 ('#авиалиния#', '[ˌavʲɪɐˈlʲinʲɪjə]', 0)
# + 0 ('#авианосец#', '[ɐvʲɪɐˈnosʲɪt͡s]', 0)
# + 0 ('#авиаполк#', '[ɐvʲɪɐˈpolk]', 0)
# + 0 ('#авиаполк#', '[ˌavʲɪɐˈpolk]', 0)
# + 0 ('#авиатор#', '[ɐvʲɪˈatər]', 0)
# + 0 ('#авиация#', '[ɐvʲɪˈat͡sɨjə]', 0)
# + 0 ('#авоська#', '[ɐˈvosʲkə]', 0)
# + 1 ('#австралиец#', '[ɐfstrɐˈlʲi(j)ɪt͡s]', 1)
# + 1 ('#австриец#', '[ɐfˈstrʲi(j)ɪt͡s]', 1)
# + 1 ('#автаркия#', '[ɐftɐrˈkʲijə]', 1)
# + 1 ('#авто#', '[ɐfˈto]', 1)
# + 1 ('#автобус#', '[ɐfˈtobʊs]', 1)
# ...

# %% [markdown]
# An exercise for the reader is to split the data in two randomly and train on one half and test on the other half.

# %%
labels[0] += '1'
labels[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a0c9e930110e> in <module>()
# ----> 1 labels[0] += '1'
#       2 labels[0]
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
ind = 0
target = []
for word_line in words:
    target.append(str(labels[ind]) + ' ' + word_line[0])
    ind += 1
target
# Out:
# ['0 #аббатство#',
#  '0 #аббревиатура#',
#  '0 #авангард#',
#  '0 #аванс#',
#  '0 #авансцена#',
#  '0 #авантюра#',
#  '0 #авантюрист#',
#  '0 #аварец#',
#  '0 #авария#',
#  '0 #август#',
#  '0 #авиабаза#',
#  '0 #авиакомпания#',
#  '0 #авиалиния#',
#  '0 #авианосец#',
#  '0 #авиаполк#',
#  '0 #авиаполк#',
#  '0 #авиатор#',
#  '0 #авиация#',
#  '0 #авоська#',
#  '1 #австралиец#',
#  '1 #австриец#',
#  '1 #автаркия#',
#  '1 #авто#',
#  '1 #автобус#',
#  '1 #автодорога#',
#  '1 #автоколебание#',
#  '1 #автоколебание#',
#  '1 #автолюбитель#',
#  '1 #автолюбитель#',
#  '1 #автомат#',
#  '1 #автоматизация#',
#  '1 #автоматика#',
#  '1 #автомашина#',
#  '1 #автомашина#',
#  '1 #автомобилестроение#',
#  '1 #автомобилист#',
#  '1 #автомобиль#',
#  '1 #автономия#',
#  '1 #автономность#',
#  '1 #автопарк#',
#  '1 #автопилот#',
#  '1 #автопилот#',
#  '1 #автопробег#',
#  '1 #автопробег#',
#  '1 #автопром#',
#  '1 #автор#',
#  '1 #авторизация#',
#  '1 #авторитет#',
#  '1 #авторучка#',
# ...

# %%
target[0].split(' ')
# Out:
# ['0', '#аббатство#']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.4, random_state=0)

# %%
y_test
# Out:
# ['0 #ревность#',
#  'и #разбирательство#',
#  '0 #неровность#',
#  '1 #хоругвь#',
#  '\t #варка#',
#  '0 #вал#',
#  '0 #пищеварение#',
#  '0 #общественность#',
#  '0 #видеозапись#',
#  '0 #переводчик#',
#  'ш #обувь#',
#  'в #вакуум#',
#  'р #коврик#',
#  '0 #получеловек#',
#  'к #кровосмешение#',
#  'а #сетование#',
#  'с #муравейник#',
#  '0 #вырубка#',
#  '0 #разведчик#',
#  'а #водитель#',
#  '0 #обжалование#',
#  'ь #первокурсник#',
#  'о #новозеландец#',
#  'е #цветение#',
#  '0 #громкоговоритель#',
#  'е #невыезд#',
#  'в #символика#',
#  'д #провайдер#',
#  'в #ветка#',
#  '0 #вознаграждение#',
#  'н #булавка#',
#  'б #оборудование#',
#  '# #соболезнование#',
#  '1 #явка#',
#  '0 #военный#',
#  '# #створка#',
#  '0 #ветеран#',
#  '1 #деревце#',
#  'е #обустройство#',
#  '0 #выгрузка#',
#  '0 #правдоподобие#',
#  'т #восторг#',
#  'е #выкуп#',
#  'д #призывник#',
#  'т #объектив#',
#  'е #шов#',
#  'о #полупроводник#',
#  'в #годовщина#',
#  '1 #полуостров#',
# ...

# %%
target_train = []
target_test = []
for y in y_train:
    target_train.append(y.split('\t')[0])

for y_t in y_test:
    target_test.append(y_t.split('\t')[0])

# %%
net_final = perceptron.Perceptron(n_iter=100, verbose=0, random_state=None, fit_intercept=True, eta0=0.002)
net_final.fit(X_train,y_train)
# Out:
# C:\Users\Admin\Anaconda2\envs\py36\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Perceptron(alpha=0.0001, class_weight=None, eta0=0.002, fit_intercept=True,
#       max_iter=None, n_iter=100, n_jobs=1, penalty=None, random_state=None,
#       shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
words[0][0]
# Out:
# '#аббатство#'

# %%
result_final = net_final.predict(X_test)
total = 0
correct = 0
for i in range(0, len(words)):
    if result_final[i] == y_test[i][2]:
        print('+', result_final[i], y_test[i]);
        correct = correct + 1
    else:
        print('-', result_final[i], y_test[i]);
    total = total + 1
print(correct/total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-718471801dc1> in <module>()
#       3 correct = 0
#       4 for i in range(0, len(words)):
# ----> 5     if result_final[i] == y_test[i][2]:
#       6         print('+', result_final[i], y_test[i]);
#       7         correct = correct + 1
#
# TypeError: 'int' object is not subscriptable
