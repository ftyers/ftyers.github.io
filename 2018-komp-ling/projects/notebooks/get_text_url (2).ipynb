# %%
https://simple.wikipedia.org/wiki/Education

# %%
from bs4 import BeautifulSoup
import requests

# %%
import io

# %%
website_url = requests.get("https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area").text
soup = BeautifulSoup(website_url,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Asian countries by area - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
My_table = soup.find("table",{"class":"wikitable sortable"})

# %%
My_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Country
# </th>
# <th>Area (km²)
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon" style="display:inline-block;width:25px;"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/></span> <a href="/wiki/Russia" title="Russia">Russia</a>*
# </td>
# <td>13,100,000
# </td>
# <td>17,125,200 including European part
# </td></tr>
# <tr>
# <td>2
# </td>
# ...

# %%
links = My_table.findAll('a')
links
# Out:
# [<a href="/wiki/Russia" title="Russia">Russia</a>,
#  <a href="/wiki/China" title="China">China</a>,
#  <a href="/wiki/Hong_Kong" title="Hong Kong">Hong Kong</a>,
#  <a href="/wiki/Macau" title="Macau">Macau</a>,
#  <a href="/wiki/India" title="India">India</a>,
#  <a href="#cite_note-1">[1]</a>,
#  <a href="/wiki/Kazakhstan" title="Kazakhstan">Kazakhstan</a>,
#  <a href="/wiki/Saudi_Arabia" title="Saudi Arabia">Saudi Arabia</a>,
#  <a href="/wiki/Iran" title="Iran">Iran</a>,
#  <a href="/wiki/Mongolia" title="Mongolia">Mongolia</a>,
#  <a href="/wiki/Indonesia" title="Indonesia">Indonesia</a>,
#  <a href="/wiki/Pakistan" title="Pakistan">Pakistan</a>,
#  <a href="/wiki/Gilgit-Baltistan" title="Gilgit-Baltistan">Gilgit-Baltistan</a>,
#  <a href="/wiki/Azad_Kashmir" title="Azad Kashmir">AJK</a>,
#  <a href="/wiki/Turkey" title="Turkey">Turkey</a>,
#  <a href="/wiki/Myanmar" title="Myanmar">Myanmar</a>,
#  <a href="/wiki/Afghanistan" title="Afghanistan">Afghanistan</a>,
# ...

# %%
country = []
for link in links:
    country.append(link.get('title'))
    
print(country)
# Out:
# ['Russia', 'China', 'Hong Kong', 'Macau', 'India', None, 'Kazakhstan', 'Saudi Arabia', 'Iran', 'Mongolia', 'Indonesia', 'Pakistan', 'Gilgit-Baltistan', 'Azad Kashmir', 'Turkey', 'Myanmar', 'Afghanistan', 'Yemen', 'Thailand', 'Turkmenistan', 'Uzbekistan', 'Iraq', 'Japan', 'Vietnam', 'Malaysia', 'Oman', 'Philippines', 'Laos', 'Kyrgyzstan', 'Syria', 'Golan Heights', 'Cambodia', 'Bangladesh', 'Nepal', 'Tajikistan', 'North Korea', 'South Korea', 'Jordan', 'Azerbaijan', 'United Arab Emirates', 'Georgia (country)', 'Sri Lanka', 'Egypt', 'Bhutan', 'Taiwan', 'Armenia', 'Israel', 'Kuwait', 'East Timor', 'Qatar', 'Lebanon', 'Cyprus', 'Northern Cyprus', 'State of Palestine', 'Brunei', 'Bahrain', 'Singapore', 'Maldives']

# %%
https://simple.wikipedia.org/wiki/Education

# %%
wiki_url = requests.get("https://simple.wikipedia.org/wiki/Education").text
w_soup = BeautifulSoup(wiki_url,"lxml")
print(w_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Education - Simple English Wikipedia, the free encyclopedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
yle_url = requests.get("https://yle.fi/uutiset/osasto/selkouutiset/selkouutisarkisto/").text
y_soup = BeautifulSoup(yle_url,"lxml")
print(y_soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="fi" class="ie ie6"> <![endif]-->
# <!--[if IE 7 ]> <html lang="fi" class="ie ie7"> <![endif]-->
# <!--[if IE 8 ]> <html lang="fi" class="ie ie8"> <![endif]-->
# <!--[if IE 9 ]> <html lang="fi" class="ie ie9"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html lang="fi">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Selkouutisarkisto | Yle Uutiset | yle.fi
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="Tervetuloa Ylen uutis-, urheilu- ja ajankohtaispalveluun." name="description"/>
#   <meta content="Tervetuloa Ylen uutis-, urheilu- ja ajankohtaispalveluun." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Yle Uutiset | Selkouutisarkisto" property="og:title"/>
#   <meta content="Yle Uutiset" property="og:site_name"/>
#   <meta content="https://yle.fi/uutiset/osasto/selkouutiset/selkouutisarkisto/" property="og:url"/>
# ...

# %%
a = y_soup.find_all('a')
for i in a:
    print (i.get('href'))
# Out:
# #container
# https://yle.fi/aihe/yle-tunnus/kayttoehdot
# https://yle.fi/aihe/yleisradio/tietosuojalauseke
# #
# https://tunnus.yle.fi/omat-tiedot
# #
# https://yle.fi/
# https://areena.yle.fi/tv
# https://yle.fi/uutiset/
# https://yle.fi/saa
# https://yle.fi/urheilu/
# https://yle.fi/aihe/tekstitv
# https://yle.fi/aihe/lapset
# https://svenska.yle.fi
#
# https://yle.fi/uutiset/osasto/selkouutiset/
# https://yle.fi/uutiset/osasto/selkouutiset/paivan_kysymykset/
# https://yle.fi/uutiset/osasto/selkouutiset/selkouutisarkisto/
# https://yle.fi/uutiset/osasto/selkouutiset/nasibin_kanssa_virastoissa/10403374
# https://yle.fi/uutiset/osasto/selkouutiset/kotoutujan_suomi/
# https://yle.fi/uutiset/osasto/selkouutiset/laheta_palautetta/7497008
# https://yle.fi/uutiset/osasto/selkouutiset/
# https://yle.fi/uutiset/osasto/selkouutiset/selkouutisarkisto/
# https://yle.fi/uutiset/osasto/selkouutiset/keskiviikko_21112018_tv/10518234
# ...

# %%
type(a)
# Out:
# bs4.element.ResultSet

# %%
except_list =["https://yle.fi/", "https://yle.fi/urheilu/"]

# %%
from os import listdir
from os.path import isfile, join

# %%
onlyfiles = [f for f in listdir("C://input//fin") if isfile(join("C://input//fin", f))]
onlyfiles
# Out:
# ['10502834.txt',
#  '10503941.txt',
#  '10504344.txt',
#  '10506237.txt',
#  '10506525.txt',
#  '10508822.txt',
#  '10510129.txt',
#  '10510782.txt',
#  '10511515.txt',
#  '10511517.txt',
#  '10513415.txt',
#  '10513956.txt',
#  '10515146.txt',
#  '10515751.txt',
#  '10516845.txt',
#  '10517580.txt',
#  '10518234.txt']

# %%
for i in a:
    if "https://yle.fi/" in i.get('href') and i.get('href') not in except_list :
        print(i.get('href'))
        read_article(i.get('href'))
# Out:
# https://yle.fi/aihe/yle-tunnus/kayttoehdot
# saved with name =  new_kayttoehdot.txt
# https://yle.fi/aihe/yleisradio/tietosuojalauseke
# saved with name =  new_tietosuojalauseke.txt
# https://yle.fi/uutiset/
# saved with name =  new_uutiset.txt
# https://yle.fi/saa
# saved with name =  new_saa.txt
# https://yle.fi/aihe/tekstitv
# saved with name =  new_tekstitv.txt
# https://yle.fi/aihe/lapset
# saved with name =  new_lapset.txt
# https://yle.fi/uutiset/osasto/selkouutiset/
# saved with name =  new_uutiset.txt
# https://yle.fi/uutiset/osasto/selkouutiset/paivan_kysymykset/
# saved with name =  new_uutiset.txt
# https://yle.fi/uutiset/osasto/selkouutiset/selkouutisarkisto/
# saved with name =  new_uutiset.txt
# https://yle.fi/uutiset/osasto/selkouutiset/nasibin_kanssa_virastoissa/10403374
# saved with name =  new_10403374.txt
# https://yle.fi/uutiset/osasto/selkouutiset/kotoutujan_suomi/
# saved with name =  new_uutiset.txt
# ...

# %%
acd = "https://yle.fi/uutiset/"
index = -1
url_name = acd.split('/')[index]
if (url_name ==''):
    url_name =  acd.split('/')[index - 1]
url_name
# Out:
# 'uutiset'

# %%
def read_article(url):
    req = requests.get(url).text
    soup = BeautifulSoup(req,"lxml")
    text_items = soup.findAll('p')
    save_to_file = []
    #add_name = True
    for item in text_items:
        #print(add_name)
        save_to_file.append(item.text)
        
    index = -1
    name = url.split('/')[index] 
    if (name ==''):
        name =  acd.split('/')[index - 1] + '.txt'
    else:
        name += '.txt'
    onlyfiles = [f for f in listdir("C://input//fin") if isfile(join("C://input//fin", f))]
    if (name in onlyfiles):
        name = 'new_' + name
    file_name = "C://input//fin//" + name  
    with io.open(file_name, "w+") as newsfile:
        for line in save_to_file:
            newsfile.write(line + '\n')
    print('saved with name = ', name)

# %%
read_article("https://yle.fi/aihe/yle-tunnus/kayttoehdot")

# %%
https://yle.fi/aihe/yle-tunnus/kayttoehdot

# %%
tr_url = requests.get("https://yle.fi/aihe/yle-tunnus/kayttoehdot").text
s = BeautifulSoup(tr_url,"lxml")
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="fi" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# schema: http://schema.org/">
#  <head>
#   <meta charset="utf-8"/>
#   <base target="_top"/>
#   <link href="https://images.cdn.yle.fi/image/upload/w_180,h_180/v1513081794/yle-logo-c-svg.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://images.cdn.yle.fi/image/upload/w_32,h_32/v1513081794/yle-logo-c-svg.png" rel="icon" sizes="32x32"/>
#   <link href="https://images.cdn.yle.fi/image/upload/w_16,h_16/v1513081794/yle-logo-c-svg.png" rel="icon" sizes="16x16"/>
#   <link href="/aihe/manifest.json" rel="manifest"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
tr = s.findAll('p')
for item in tr:
    print(item.text)
# Out:
# Yle Tunnuksen käyttöä koskevat käyttöehdot
# Olemme päivittäneet Yle Tunnuksen käyttöehtoja 25.5.2018.
# Yle Tunnuksella voit kirjautua kaikkiin Ylen digitaalisiin palveluihin millä tahansa tuetulla laitteella. Tarjoamme sinulle parempaa henkilökohtaista palvelua, kun luot Yle Tunnuksen ja käytät Ylen palveluita kirjautuneena.
# Keräämme käytöstäsi tietoja löytääksemme sinulle osuvampia sisältösuositteluja, ymmärtääksemme millainen sisältö kiinnostaa ihmisiä ja kehittääksemme sisällöistämme ja palveluistamme entistä parempia.
# Yle Tunnus on kotimainen ja turvallinen palvelu. Pidämme kaikesta keräämästämme tiedosta tarkkaa huolta: emme luovuta tietojasi ulkopuolisille tahoille ja käytämme tietojasi vain yllä kuvattuihin tarkoituksiin. Voit milloin tahansa ladata itsellesi kaikki sinusta keräämämme tiedot, ja voit halutessasi  poistaa Tunnuksesi.
# ...

# %%
for i in s:
    print (s.get('p'))
# Out:
# None
# None
# None
